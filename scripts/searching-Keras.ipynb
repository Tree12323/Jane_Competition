# %% [markdown]
# # Description

# %% [markdown]
# ### This code will show you a way to search for the best threshold. You can use this method searching for a better threshold instead of using 0.5 as final threshold.

# %% [markdown]
# ### You can find the training code from <br/> https://www.kaggle.com/a763337092/neural-network-starter-pytorch-version/comments and <br/> https://www.kaggle.com/a763337092/pytorch-resnet-starter-training

# %% [markdown]
# ## Upvoting if it helps🔥🔥🔥

# %% [markdown]
# # Load models

# %%
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Dropout, Concatenate, Lambda, GaussianNoise, Activation
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers.experimental.preprocessing import Normalization
import tensorflow as tf
import tensorflow_addons as tfa

import numpy as np
import pandas as pd
import datatable as dt
from tqdm import tqdm
from random import choices
import gc

SEED = 1111
np.random.seed(SEED)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
# fit
def create_mlp(num_columns, num_labels, hidden_units, dropout_rates, label_smoothing, learning_rate):

    inp = tf.keras.layers.Input(shape=(num_columns,))
    x = tf.keras.layers.BatchNormalization()(inp)
    x = tf.keras.layers.Dropout(dropout_rates[0])(x)
    for i in range(len(hidden_units)):
        x = tf.keras.layers.Dense(hidden_units[i])(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Activation(tf.keras.activations.swish)(x)
        x = tf.keras.layers.Dropout(dropout_rates[i + 1])(x)
    
    x = tf.keras.layers.Dense(num_labels)(x)
    out = tf.keras.layers.Activation("sigmoid")(x)

    model = tf.keras.models.Model(inputs=inp, outputs=out)
    model.compile(
        optimizer=tfa.optimizers.RectifiedAdam(learning_rate=learning_rate),
        loss=tf.keras.losses.BinaryCrossentropy(label_smoothing=label_smoothing),
        metrics=tf.keras.metrics.AUC(name="AUC"),
    )

    return model

# %%
features = [f'feature_{i}' for i in range(130)]
hidden_units = [160, 160, 160]
dropout_rates = [0.2, 0.2, 0.2, 0.2]
label_smoothing = 1e-2
learning_rate = 1e-3
tf.keras.backend.clear_session()
tf.random.set_seed(SEED)
clf = create_mlp(
    len(features), 5, hidden_units, dropout_rates, label_smoothing, learning_rate
    )

# %%
clf.load_weights('tf_model.h5')

# %%
model_list = [clf]

# %% [markdown]
# # Get offline predictions

# %% [markdown]
# For I use the last 50 date data as my offline validation data, so I use the 5 models‘ average prediction on last 50 date data to search for the best threshold.

# %%
# train = pd.read_csv('../input/jane-street-market-prediction/train.csv')
train = dt.fread('/kaggle/working/input/train.csv').to_pandas()
valid = train.loc[(train.date >= 450) & (train.date < 500)].reset_index(drop=True)
valid.fillna(train.mean(), inplace=True)
target_cols = ['resp_1', 'resp_2', 'resp_3', 'resp', 'resp_4']
del train

# %%
X_valid = valid.loc[:, features]
y_valid = np.stack([(valid[c] > 0).astype('int') for c in target_cols]).T
gc.collect()
# Out:
# 2158

# %%
valid_pred = np.zeros((len(valid), len(target_cols)))
for model in model_list:
    valid_pred += model(X_valid.values).numpy() / len(model_list)
#     valid_pred += inference_fn(model, valid_loader, device) / len(model_list)

# %%
valid_pred = np.median(valid_pred, axis=1)
valid_pred.shape
# Out:
# (278315,)

# %% [markdown]
# # Searching for best threshold

# %%
def utility_score_bincount(date, weight, resp, action):
    count_i = len(np.unique(date))
    # print('weight: ', weight)
    # print('resp: ', resp)
    # print('action: ', action)
    # print('weight * resp * action: ', weight * resp * action)
    Pi = np.bincount(date, weight * resp * action)
    t = np.sum(Pi) / np.sqrt(np.sum(Pi ** 2)) * np.sqrt(250 / count_i)
    u = np.clip(t, 0, 6) * np.sum(Pi)
    return u

# %%
best_threshold, best_u_score = 0.5, 0
for i in range(4500, 5500):
    thres = float(i) / 10000
    slice_valid_pred = valid_pred.copy()
    slice_valid_pred = np.where(slice_valid_pred >= thres, 1, 0).astype(int)
    valid_u_score = utility_score_bincount(date=valid.date.values, weight=valid.weight.values,
                                           resp=valid.resp.values, action=slice_valid_pred)
    print(f'thresold={thres:.4f}, valid_u_score={valid_u_score:.4f}')
    
    if valid_u_score >= best_u_score:
        best_u_score = valid_u_score
        best_threshold = thres
# Out:
# thresold=0.4500, valid_u_score=3680.7511
# thresold=0.4501, valid_u_score=3680.1077
# thresold=0.4502, valid_u_score=3684.8009
# thresold=0.4503, valid_u_score=3682.1079
# thresold=0.4504, valid_u_score=3688.3201
# thresold=0.4505, valid_u_score=3700.9308
# thresold=0.4506, valid_u_score=3701.5615
# thresold=0.4507, valid_u_score=3704.8463
# thresold=0.4508, valid_u_score=3717.4528
# thresold=0.4509, valid_u_score=3723.0871
# thresold=0.4510, valid_u_score=3720.2174
# thresold=0.4511, valid_u_score=3720.4855
# thresold=0.4512, valid_u_score=3723.2988
# thresold=0.4513, valid_u_score=3724.9619
# thresold=0.4514, valid_u_score=3722.9869
# thresold=0.4515, valid_u_score=3729.3038
# thresold=0.4516, valid_u_score=3729.6909
# thresold=0.4517, valid_u_score=3725.1121
# thresold=0.4518, valid_u_score=3729.2407
# thresold=0.4519, valid_u_score=3728.0242
# thresold=0.4520, valid_u_score=3736.4681
# thresold=0.4521, valid_u_score=3741.4285
# thresold=0.4522, valid_u_score=3747.3317
# thresold=0.4523, valid_u_score=3748.4450
# thresold=0.4524, valid_u_score=3755.4345
# thresold=0.4525, valid_u_score=3754.2935
# thresold=0.4526, valid_u_score=3757.4939
# thresold=0.4527, valid_u_score=3768.7185
# thresold=0.4528, valid_u_score=3772.5888
# thresold=0.4529, valid_u_score=3784.1132
# thresold=0.4530, valid_u_score=3787.9521
# thresold=0.4531, valid_u_score=3806.7223
# thresold=0.4532, valid_u_score=3811.9456
# thresold=0.4533, valid_u_score=3829.7495
# thresold=0.4534, valid_u_score=3824.3804
# thresold=0.4535, valid_u_score=3821.9890
# thresold=0.4536, valid_u_score=3823.2027
# thresold=0.4537, valid_u_score=3825.9618
# thresold=0.4538, valid_u_score=3830.4390
# thresold=0.4539, valid_u_score=3846.5307
# thresold=0.4540, valid_u_score=3842.1886
# thresold=0.4541, valid_u_score=3860.9534
# thresold=0.4542, valid_u_score=3866.2462
# thresold=0.4543, valid_u_score=3872.4965
# thresold=0.4544, valid_u_score=3876.2901
# thresold=0.4545, valid_u_score=3878.0084
# thresold=0.4546, valid_u_score=3891.0186
# thresold=0.4547, valid_u_score=3897.0943
# thresold=0.4548, valid_u_score=3896.9830
# thresold=0.4549, valid_u_score=3893.5567
# thresold=0.5006, valid_u_score=4899.6721
# thresold=0.5007, valid_u_score=4887.4902
# thresold=0.5008, valid_u_score=4883.3974
# thresold=0.5009, valid_u_score=4881.9745
# thresold=0.5010, valid_u_score=4874.9299
# thresold=0.5011, valid_u_score=4870.0854
# thresold=0.5012, valid_u_score=4867.8309
# thresold=0.5013, valid_u_score=4868.5227
# thresold=0.5014, valid_u_score=4875.0081
# thresold=0.5015, valid_u_score=4874.9702
# thresold=0.5016, valid_u_score=4878.7378
# thresold=0.5017, valid_u_score=4871.6855
# thresold=0.5018, valid_u_score=4878.9345
# thresold=0.5019, valid_u_score=4880.1006
# thresold=0.5020, valid_u_score=4881.5643
# thresold=0.5021, valid_u_score=4875.8257
# thresold=0.5022, valid_u_score=4880.4478
# thresold=0.5023, valid_u_score=4891.6021
# thresold=0.5024, valid_u_score=4920.5966
# thresold=0.5025, valid_u_score=4919.6787
# thresold=0.5026, valid_u_score=4930.4801
# thresold=0.5027, valid_u_score=4940.2843
# thresold=0.5028, valid_u_score=4940.1797
# thresold=0.5029, valid_u_score=4922.9446
# thresold=0.5030, valid_u_score=4914.5825
# thresold=0.5031, valid_u_score=4897.1096
# thresold=0.5032, valid_u_score=4895.0991
# thresold=0.5033, valid_u_score=4901.8307
# thresold=0.5034, valid_u_score=4892.3938
# thresold=0.5035, valid_u_score=4890.4878
# thresold=0.5036, valid_u_score=4878.0311
# thresold=0.5037, valid_u_score=4863.2024
# thresold=0.5038, valid_u_score=4868.8689
# thresold=0.5039, valid_u_score=4871.2048
# thresold=0.5040, valid_u_score=4867.1566
# thresold=0.5041, valid_u_score=4874.4729
# thresold=0.5042, valid_u_score=4871.2043
# thresold=0.5043, valid_u_score=4856.4840
# thresold=0.5044, valid_u_score=4858.1881
# thresold=0.5045, valid_u_score=4863.3982
# thresold=0.5046, valid_u_score=4860.6391
# thresold=0.5047, valid_u_score=4878.4277
# thresold=0.5048, valid_u_score=4871.5919
# thresold=0.5049, valid_u_score=4868.8969
# thresold=0.5050, valid_u_score=4875.3610
# thresold=0.5051, valid_u_score=4876.7334
# thresold=0.5052, valid_u_score=4894.7909
# thresold=0.5053, valid_u_score=4904.2768
# thresold=0.5054, valid_u_score=4915.7681
# thresold=0.5055, valid_u_score=4912.5147
# thresold=0.5056, valid_u_score=4908.5318
# thresold=0.5057, valid_u_score=4910.5066
# thresold=0.5058, valid_u_score=4896.7702
# thresold=0.5059, valid_u_score=4904.2625
# thresold=0.5060, valid_u_score=4892.5765
# thresold=0.5061, valid_u_score=4897.5598
# thresold=0.5062, valid_u_score=4900.8923
# thresold=0.5063, valid_u_score=4910.7907
# thresold=0.5064, valid_u_score=4897.3400
# thresold=0.5065, valid_u_score=4892.3332
# thresold=0.5066, valid_u_score=4895.3910
# thresold=0.5067, valid_u_score=4891.0935
# thresold=0.5068, valid_u_score=4889.5132
# thresold=0.5069, valid_u_score=4876.4654
# thresold=0.5070, valid_u_score=4866.8848
# thresold=0.5136, valid_u_score=4801.4948
# thresold=0.5137, valid_u_score=4810.0345
# thresold=0.5138, valid_u_score=4807.7293
# thresold=0.5139, valid_u_score=4798.5709
# thresold=0.5140, valid_u_score=4785.4359
# thresold=0.5141, valid_u_score=4780.2451
# thresold=0.5142, valid_u_score=4778.1082
# thresold=0.5143, valid_u_score=4772.4007
# thresold=0.5144, valid_u_score=4802.4273
# thresold=0.5145, valid_u_score=4793.7362
# thresold=0.5146, valid_u_score=4790.1556
# thresold=0.5147, valid_u_score=4796.1627
# thresold=0.5148, valid_u_score=4794.4247
# thresold=0.5149, valid_u_score=4788.9416
# thresold=0.5150, valid_u_score=4782.7183
# thresold=0.5151, valid_u_score=4780.2030
# thresold=0.5152, valid_u_score=4798.8852
# thresold=0.5153, valid_u_score=4781.6903
# thresold=0.5154, valid_u_score=4782.7418
# thresold=0.5155, valid_u_score=4774.8696
# thresold=0.5156, valid_u_score=4762.2225
# thresold=0.5157, valid_u_score=4753.7654
# thresold=0.5158, valid_u_score=4743.6775
# thresold=0.5159, valid_u_score=4749.3391
# thresold=0.5160, valid_u_score=4753.7535
# thresold=0.5161, valid_u_score=4749.6383
# thresold=0.5162, valid_u_score=4752.5263
# thresold=0.5163, valid_u_score=4751.9531
# thresold=0.5164, valid_u_score=4750.7806
# thresold=0.5165, valid_u_score=4744.0503
# thresold=0.5166, valid_u_score=4747.0997
# thresold=0.5167, valid_u_score=4750.3718
# thresold=0.5168, valid_u_score=4743.9265
# thresold=0.5169, valid_u_score=4740.2467
# thresold=0.5170, valid_u_score=4740.5689
# thresold=0.5171, valid_u_score=4735.6170
# thresold=0.5172, valid_u_score=4717.7595
# thresold=0.5173, valid_u_score=4705.4212
# thresold=0.5174, valid_u_score=4696.4730
# thresold=0.5175, valid_u_score=4692.7558
# thresold=0.5176, valid_u_score=4683.3035
# thresold=0.5177, valid_u_score=4668.5992
# thresold=0.5178, valid_u_score=4665.2785
# thresold=0.5179, valid_u_score=4664.5076
# thresold=0.5180, valid_u_score=4651.7939
# thresold=0.5181, valid_u_score=4648.3537
# thresold=0.5182, valid_u_score=4652.3691
# thresold=0.5183, valid_u_score=4645.0232
# thresold=0.5184, valid_u_score=4647.0561
# thresold=0.5185, valid_u_score=4658.4880
# thresold=0.5186, valid_u_score=4648.5307
# thresold=0.5187, valid_u_score=4651.8610
# thresold=0.5188, valid_u_score=4646.9728
# thresold=0.5189, valid_u_score=4641.0933
# thresold=0.5190, valid_u_score=4635.2224
# thresold=0.5191, valid_u_score=4630.0609
# thresold=0.5192, valid_u_score=4620.9669
# thresold=0.5193, valid_u_score=4623.9599
# thresold=0.5194, valid_u_score=4624.5033
# thresold=0.5195, valid_u_score=4624.3838
# thresold=0.5196, valid_u_score=4631.4122
# thresold=0.5197, valid_u_score=4630.9287
# thresold=0.5198, valid_u_score=4631.4782
# thresold=0.5199, valid_u_score=4618.8204
# thresold=0.5200, valid_u_score=4622.9638
# thresold=0.5201, valid_u_score=4627.5641
# thresold=0.5202, valid_u_score=4631.7009
# thresold=0.5203, valid_u_score=4629.0811
# thresold=0.5204, valid_u_score=4638.0713
# thresold=0.5205, valid_u_score=4624.4120
# thresold=0.5206, valid_u_score=4615.7327
# thresold=0.5207, valid_u_score=4606.1909
# thresold=0.5208, valid_u_score=4604.6114
# thresold=0.5209, valid_u_score=4606.0407
# thresold=0.5210, valid_u_score=4605.0080
# thresold=0.5211, valid_u_score=4601.5902
# thresold=0.5212, valid_u_score=4602.2408
# thresold=0.5213, valid_u_score=4573.7964
# thresold=0.5214, valid_u_score=4566.9809
# thresold=0.5215, valid_u_score=4574.3795
# thresold=0.5216, valid_u_score=4571.6676
# thresold=0.5217, valid_u_score=4572.2824
# thresold=0.5218, valid_u_score=4560.1278
# thresold=0.5219, valid_u_score=4560.5058
# thresold=0.5220, valid_u_score=4556.9820
# thresold=0.5221, valid_u_score=4553.5110
# thresold=0.5222, valid_u_score=4553.9647
# thresold=0.5223, valid_u_score=4546.8505
# thresold=0.5224, valid_u_score=4541.9477
# thresold=0.5225, valid_u_score=4538.7615
# thresold=0.5226, valid_u_score=4527.2000
# thresold=0.5227, valid_u_score=4526.1724
# thresold=0.5228, valid_u_score=4517.7205
# thresold=0.5229, valid_u_score=4520.2163
# thresold=0.5230, valid_u_score=4515.3798
# thresold=0.5231, valid_u_score=4499.5694
# thresold=0.5232, valid_u_score=4497.9562
# thresold=0.5233, valid_u_score=4494.5553
# thresold=0.5234, valid_u_score=4499.8315
# thresold=0.5235, valid_u_score=4506.9764
# thresold=0.5236, valid_u_score=4511.1945
# thresold=0.5237, valid_u_score=4494.8792
# thresold=0.5238, valid_u_score=4494.7336
# thresold=0.5239, valid_u_score=4487.5337
# thresold=0.5240, valid_u_score=4479.6951
# thresold=0.5241, valid_u_score=4473.3202
# thresold=0.5242, valid_u_score=4488.7942
# thresold=0.5243, valid_u_score=4471.9028
# thresold=0.5244, valid_u_score=4460.7407
# thresold=0.5245, valid_u_score=4461.3581
# thresold=0.5246, valid_u_score=4450.2797
# thresold=0.5247, valid_u_score=4440.7613
# thresold=0.5248, valid_u_score=4434.7300
# thresold=0.5249, valid_u_score=4436.7145
# thresold=0.5250, valid_u_score=4435.3388
# thresold=0.5251, valid_u_score=4433.6403
# thresold=0.5252, valid_u_score=4430.3264
# thresold=0.5253, valid_u_score=4422.9858
# thresold=0.5254, valid_u_score=4420.5460
# thresold=0.5255, valid_u_score=4412.5057
# thresold=0.5256, valid_u_score=4414.3470
# thresold=0.5257, valid_u_score=4407.8976
# thresold=0.5258, valid_u_score=4406.9890
# thresold=0.5259, valid_u_score=4400.6654
# thresold=0.5260, valid_u_score=4396.3264
# thresold=0.5261, valid_u_score=4395.9223
# thresold=0.5262, valid_u_score=4400.4479
# thresold=0.5263, valid_u_score=4393.2773
# thresold=0.5264, valid_u_score=4389.8365
# thresold=0.5265, valid_u_score=4393.2867
# thresold=0.5331, valid_u_score=4128.0822
# thresold=0.5332, valid_u_score=4125.3713
# thresold=0.5333, valid_u_score=4121.3216
# thresold=0.5334, valid_u_score=4115.8637
# thresold=0.5335, valid_u_score=4107.7279
# thresold=0.5336, valid_u_score=4120.0235
# thresold=0.5337, valid_u_score=4116.4989
# thresold=0.5338, valid_u_score=4106.8792
# thresold=0.5339, valid_u_score=4099.4243
# thresold=0.5340, valid_u_score=4094.6430
# thresold=0.5341, valid_u_score=4085.3364
# thresold=0.5342, valid_u_score=4082.7214
# thresold=0.5343, valid_u_score=4071.4687
# thresold=0.5344, valid_u_score=4063.7173
# thresold=0.5345, valid_u_score=4063.6246
# thresold=0.5346, valid_u_score=4062.2159
# thresold=0.5347, valid_u_score=4064.1389
# thresold=0.5348, valid_u_score=4056.3947
# thresold=0.5349, valid_u_score=4067.1812
# thresold=0.5350, valid_u_score=4066.3458
# thresold=0.5351, valid_u_score=4061.6259
# thresold=0.5352, valid_u_score=4053.2206
# thresold=0.5353, valid_u_score=4049.4638
# thresold=0.5354, valid_u_score=4048.6848
# thresold=0.5355, valid_u_score=4047.2581
# thresold=0.5356, valid_u_score=4041.2172
# thresold=0.5357, valid_u_score=4029.4306
# thresold=0.5358, valid_u_score=4017.9433
# thresold=0.5359, valid_u_score=4009.6872
# thresold=0.5360, valid_u_score=4009.4243
# thresold=0.5361, valid_u_score=4001.8099
# thresold=0.5362, valid_u_score=4003.9832
# thresold=0.5363, valid_u_score=3987.1100
# thresold=0.5364, valid_u_score=3989.8189
# thresold=0.5365, valid_u_score=3984.4907
# thresold=0.5366, valid_u_score=3986.0867
# thresold=0.5367, valid_u_score=3998.4214
# thresold=0.5368, valid_u_score=3990.1955
# thresold=0.5369, valid_u_score=3987.0646
# thresold=0.5370, valid_u_score=3977.7794
# thresold=0.5371, valid_u_score=3968.7896
# thresold=0.5372, valid_u_score=3956.7808
# thresold=0.5373, valid_u_score=3951.9051
# thresold=0.5374, valid_u_score=3942.8919
# thresold=0.5375, valid_u_score=3937.8689
# thresold=0.5376, valid_u_score=3933.8892
# thresold=0.5377, valid_u_score=3933.0310
# thresold=0.5378, valid_u_score=3924.2142
# thresold=0.5379, valid_u_score=3918.3914
# thresold=0.5380, valid_u_score=3915.7394
# thresold=0.5381, valid_u_score=3911.1960
# thresold=0.5382, valid_u_score=3908.2474
# thresold=0.5383, valid_u_score=3901.6753
# thresold=0.5384, valid_u_score=3882.5042
# thresold=0.5385, valid_u_score=3881.5152
# thresold=0.5386, valid_u_score=3871.2852
# thresold=0.5387, valid_u_score=3866.5409
# thresold=0.5388, valid_u_score=3853.2089
# thresold=0.5389, valid_u_score=3846.6431
# thresold=0.5390, valid_u_score=3828.5634
# thresold=0.5391, valid_u_score=3821.4762
# thresold=0.5392, valid_u_score=3814.9415
# thresold=0.5393, valid_u_score=3791.4754
# thresold=0.5394, valid_u_score=3782.4153
# thresold=0.5395, valid_u_score=3775.6687
# thresold=0.5396, valid_u_score=3772.3036
# thresold=0.5397, valid_u_score=3768.4328
# thresold=0.5398, valid_u_score=3773.0368
# thresold=0.5399, valid_u_score=3764.4912
# thresold=0.5400, valid_u_score=3762.6357
# thresold=0.5401, valid_u_score=3756.3419
# thresold=0.5402, valid_u_score=3749.3670
# thresold=0.5403, valid_u_score=3745.5542
# thresold=0.5404, valid_u_score=3738.9710
# thresold=0.5405, valid_u_score=3726.4141
# thresold=0.5406, valid_u_score=3720.7984
# thresold=0.5407, valid_u_score=3713.5893
# thresold=0.5408, valid_u_score=3707.2963
# thresold=0.5409, valid_u_score=3705.4552
# thresold=0.5410, valid_u_score=3702.6130
# thresold=0.5411, valid_u_score=3693.9811
# thresold=0.5412, valid_u_score=3685.4047
# thresold=0.5413, valid_u_score=3676.2031
# thresold=0.5414, valid_u_score=3669.4220
# thresold=0.5415, valid_u_score=3666.5989
# thresold=0.5416, valid_u_score=3661.2040
# thresold=0.5417, valid_u_score=3659.2060
# thresold=0.5418, valid_u_score=3655.3292
# thresold=0.5419, valid_u_score=3640.2036
# thresold=0.5420, valid_u_score=3637.1463
# thresold=0.5421, valid_u_score=3626.5002
# thresold=0.5422, valid_u_score=3622.2043
# thresold=0.5423, valid_u_score=3624.6692
# thresold=0.5424, valid_u_score=3622.6300
# thresold=0.5425, valid_u_score=3618.6310
# thresold=0.5426, valid_u_score=3616.3398
# thresold=0.5427, valid_u_score=3610.5764
# thresold=0.5428, valid_u_score=3609.4672
# thresold=0.5429, valid_u_score=3599.3332
# thresold=0.5430, valid_u_score=3583.1340
# thresold=0.5431, valid_u_score=3574.5227
# thresold=0.5432, valid_u_score=3568.4297
# thresold=0.5433, valid_u_score=3565.3170
# thresold=0.5434, valid_u_score=3558.9871
# thresold=0.5435, valid_u_score=3546.1485
# thresold=0.5436, valid_u_score=3545.8620
# thresold=0.5437, valid_u_score=3533.4702
# thresold=0.5438, valid_u_score=3527.9370
# thresold=0.5439, valid_u_score=3529.7398
# thresold=0.5440, valid_u_score=3526.0023
# thresold=0.5441, valid_u_score=3523.5128
# thresold=0.5442, valid_u_score=3516.8405
# thresold=0.5443, valid_u_score=3511.4300
# thresold=0.5444, valid_u_score=3512.6154
# thresold=0.5445, valid_u_score=3509.3905
# thresold=0.5446, valid_u_score=3501.9807
# thresold=0.5447, valid_u_score=3493.5020
# thresold=0.5448, valid_u_score=3479.8651
# thresold=0.5449, valid_u_score=3467.7609
# thresold=0.5450, valid_u_score=3473.8705
# thresold=0.5451, valid_u_score=3469.7954
# thresold=0.5452, valid_u_score=3469.1384
# thresold=0.5453, valid_u_score=3465.7511
# thresold=0.5454, valid_u_score=3465.8706
# thresold=0.5455, valid_u_score=3460.4009
# thresold=0.5456, valid_u_score=3459.3413
# thresold=0.5457, valid_u_score=3469.3884
# thresold=0.5458, valid_u_score=3464.8360
# thresold=0.5459, valid_u_score=3465.1285
# thresold=0.5460, valid_u_score=3454.8542
# thresold=0.5461, valid_u_score=3451.0912
# thresold=0.5462, valid_u_score=3445.5119
# thresold=0.5463, valid_u_score=3442.5061
# thresold=0.5464, valid_u_score=3436.2552
# thresold=0.5465, valid_u_score=3434.5651
# thresold=0.5466, valid_u_score=3436.9343
# thresold=0.5467, valid_u_score=3428.3736
# thresold=0.5468, valid_u_score=3427.0572
# thresold=0.5469, valid_u_score=3425.2154
# thresold=0.5470, valid_u_score=3406.6260
# thresold=0.5471, valid_u_score=3404.9561
# thresold=0.5472, valid_u_score=3402.6783
# thresold=0.5473, valid_u_score=3398.2308
# thresold=0.5474, valid_u_score=3396.3434
# thresold=0.5475, valid_u_score=3394.6100
# thresold=0.5476, valid_u_score=3374.7345
# thresold=0.5477, valid_u_score=3367.7948
# thresold=0.5478, valid_u_score=3359.1982
# thresold=0.5479, valid_u_score=3347.4248
# thresold=0.5480, valid_u_score=3339.1872
# thresold=0.5481, valid_u_score=3344.3815
# thresold=0.5482, valid_u_score=3343.6052
# thresold=0.5483, valid_u_score=3333.0256
# thresold=0.5484, valid_u_score=3326.0220
# thresold=0.5485, valid_u_score=3324.9646
# thresold=0.5486, valid_u_score=3319.9210
# thresold=0.5487, valid_u_score=3308.3712
# thresold=0.5488, valid_u_score=3302.7810
# thresold=0.5489, valid_u_score=3302.7350
# thresold=0.5490, valid_u_score=3298.1483
# thresold=0.5491, valid_u_score=3309.3871
# thresold=0.5492, valid_u_score=3303.1620
# thresold=0.5493, valid_u_score=3305.5639
# thresold=0.5494, valid_u_score=3298.1697
# thresold=0.5495, valid_u_score=3294.0077
# thresold=0.5496, valid_u_score=3288.0628
# thresold=0.5497, valid_u_score=3286.8534
# thresold=0.5498, valid_u_score=3284.5690
# thresold=0.5499, valid_u_score=3281.8996

# %%
print(f'Best thresold={best_threshold:.4f}, best valid u score={best_u_score:.4f}')
# Out:
# Best thresold=0.4949, best valid u score=5032.3293

# %% [markdown]
# # Predict with best threshold

# %%
if True:
    import janestreet
    env = janestreet.make_env()
    env_iter = env.iter_test()

    for (test_df, pred_df) in tqdm(env_iter):
        if test_df['weight'].item() > 0:
            x_tt = test_df.loc[:, feat_cols].values
            if np.isnan(x_tt.sum()):
                x_tt = np.nan_to_num(x_tt) + np.isnan(x_tt) * f_mean

            cross_41_42_43 = x_tt[:, 41] + x_tt[:, 42] + x_tt[:, 43]
            cross_1_2 = x_tt[:, 1] / (x_tt[:, 2] + 1e-5)
            feature_inp = np.concatenate((
                x_tt,
                np.array(cross_41_42_43).reshape(x_tt.shape[0], 1),
                np.array(cross_1_2).reshape(x_tt.shape[0], 1),
            ), axis=1)

            pred = np.zeros((1, len(target_cols)))
            for model in model_list:
                pred += model(torch.tensor(feature_inp, dtype=torch.float).to(device)).sigmoid().detach().cpu().numpy() / NFOLDS
            pred = np.median(pred)
            pred_df.action = np.where(pred >= best_threshold, 1, 0).astype(int)
        else:
            pred_df.action = 0
        env.predict(pred_df)
# Out:
# 15219it [03:44, 67.64it/s]
